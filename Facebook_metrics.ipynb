# %%
import pandas as pd
import numpy as np

import seaborn as sns                                   #visualization
from matplotlib import pyplot as plt                    #visualization

# %matplotlib inline
from ggplot import *

# %%
facebook_data=pd.read_csv("C:/Users/kasth/Udacity/Python/dataset_Facebook.csv", sep=';')

# %%
facebook_data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
facebook_data.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
d = {'Type': ["like","comment", "share"], \
     'Mean': [facebook_data["like"].mean(),\
              facebook_data["comment"].mean(),\
              facebook_data["share"].mean()]}

df_mean = pd.DataFrame(data=d)
df_mean
# Out:
#          Mean     Type
# 0  177.945892     like
# 1    7.482000  comment
# 2   27.266129    share

# %%
ax = sns.stripplot(x="Type", y="Total Likes Comment and Shares",\
     data=facebook_data,jitter=True, color=".1", size = 4 )

# %%
ax = sns.swarmplot(x="Type", y="Total Likes Comment and Shares",\
                   hue="Paid", data=facebook_data, palette="Set2")

# %%
ax = sns.violinplot(x="Paid", y="Total Likes Comment and Shares",\
                    data=facebook_data, scale="width")

# %%
c = facebook_data.corr()
sns.heatmap(c,cmap="YlGnBu")

# %%
sns.violinplot(x= "Page total likes", data=facebook_data, scale='area')

# %%
g = sns.factorplot("Type", "Lifetime Post Consumers", "Post Month", data=facebook_data, kind="bar", size=12)
